# %% [markdown]
# # Create MERlin data organization

# %%
import os
import sys
from pathlib import Path
import pandas as pd

MERCI_DIR    = Path(os.getcwd()).parent.parent   # MERci/ (notebook lives in MERci/notebooks/prepare_imaging/)
SAMPLE_DIR   = MERCI_DIR.parent                  # experiment root, e.g. LT027_saving_time/
METADATA_DIR = SAMPLE_DIR / "metadata"
SETTINGS_DIR = SAMPLE_DIR / "settings"
sys.path.insert(0, str(MERCI_DIR / "src"))

from MERci.acquisition.data_organization import create_data_organization
from MERci.acquisition.dave import annotate_dave_with_round_info

MICROSCOPE  = "MF3"
SAMPLE_NAME = SAMPLE_DIR.name

print(f"SAMPLE_DIR   : {SAMPLE_DIR}")
print(f"SAMPLE_NAME  : {SAMPLE_NAME}")
print(f"METADATA_DIR : {METADATA_DIR}")
print(f"SETTINGS_DIR : {SETTINGS_DIR}")

# %% [markdown]
# ## Auto-detect frame tables
#
# Lists all `frame_table_*.csv` files in the metadata folder. The bits frame table
# is auto-selected as the most recently modified one that does **not** contain 405 nm.
# Override `BITS_FT` / `CELLS_FT` manually if needed.

# %%
ft_files = sorted(
    METADATA_DIR.glob("frame_table_*.csv"),
    key=lambda p: p.stat().st_mtime, reverse=True
)

print("Frame tables found (newest first):")
for f in ft_files:
    ft = pd.read_csv(f, index_col=0)
    colors = sorted(ft["color"].dropna().unique().astype(int))
    print(f"  {f.name}  →  colors: {colors}")

# Auto-pick: bits = most recent without 405; cells = most recent with 405
BITS_FT  = next(f for f in ft_files
                if 405 not in pd.read_csv(f, index_col=0)["color"].dropna().unique())
CELLS_FT = next(f for f in ft_files
                if 405 in pd.read_csv(f, index_col=0)["color"].dropna().unique())

print(f"\nBits  frame table : {BITS_FT.name}")
print(f"Cells frame table : {CELLS_FT.name}")
# Out:
# Frame tables found (newest first):
#   frame_table_405f25-488f2.csv  →  colors: [np.int64(405), np.int64(488)]
#   frame_table_blkf4-488f2-560f25-650f25-750f25.csv  →  colors: [np.int64(488), np.int64(560), np.int64(650), np.int64(750)]
#
# Bits  frame table : frame_table_blkf4-488f2-560f25-650f25-750f25.csv
# Cells frame table : frame_table_405f25-488f2.csv

# %% [markdown]
# ## Round – bit – color mapping
#
# Define which bit is imaged in each round and at which wavelength.
# Edit this table to match the actual experiment codebook.
#
# Columns saved to `round_bit_color_map.csv`:
# - `round`  : imaging round (1-indexed)
# - `bit`    : bit number
# - `color`  : excitation wavelength in nm

# %%
# (round, bit_number, color_nm)
round_bit_color = [
    (1,  1,  750), (1,  2,  650), (1,  17, 560),
    (2,  3,  750), (2,  4,  650), (2,  18, 560),
    (3,  5,  750), (3,  6,  650), (3,  19, 560),
    (4,  7,  750), (4,  8,  650), (4,  20, 560),
    (5,  9,  750), (5,  10, 650), (5,  21, 560),
    (6,  11, 750), (6,  12, 650), (6,  22, 560),
    (7,  13, 750), (7,  14, 650), (7,  23, 560),
    (8,  15, 750), (8,  16, 650), (8,  24, 560),
    (9,  25, 750), (9,  26, 650), (9,  27, 560),
]

rbc_df   = pd.DataFrame(round_bit_color, columns=["round", "bit", "color"])
rbc_path = METADATA_DIR / "round_bit_color_map.csv"
rbc_df.to_csv(rbc_path, index=False)
print(f"Saved: {rbc_path}")
print(rbc_df.to_string(index=False))
# Out:
# Saved: c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\metadata\round_bit_color_map.csv
#  round  bit  color
#      1    1    750
#      1    2    650
#      1   17    560
#      2    3    750
#      2    4    650
#      2   18    560
#      3    5    750
#      3    6    650
#      3   19    560
#      4    7    750
#      4    8    650
#      4   20    560
#      5    9    750
#      5   10    650
#      5   21    560
#      6   11    750
#      6   12    650
#      6   22    560
#      7   13    750
#      7   14    650
#      7   23    560
#      8   15    750
#      8   16    650
#      8   24    560
#      9   25    750
#      9   26    650
#      9   27    560

# %% [markdown]
# ## Series patterns from round_info.csv
#
# Reads the bits and cells series patterns so the correct `imageType` and
# `imageRegExp` fields are written into the data organization.
# Re-run notebook 03 first if `round_info.csv` is out of date.

# %%
round_info_path = METADATA_DIR / "round_info.csv"
round_info      = pd.read_csv(round_info_path)

bits_series  = round_info[~round_info["series"].str.contains("cells")].iloc[0]["series"]
cells_series = round_info[ round_info["series"].str.contains("cells")].iloc[0]["series"]

print(f"Bits  series : {bits_series}")
print(f"Cells series : {cells_series}")
# Out:
# Bits  series : hal-mf3-epi_01_{fov:03d}
# Cells series : hal-mf3-epi-cells_{fov:03d}

# %% [markdown]
# ## Build and save data organization

# %%
readouts  = pd.read_csv(MERCI_DIR / "data" / "readouts.csv")
ft_bits   = pd.read_csv(BITS_FT,  index_col=0)
ft_cells  = pd.read_csv(CELLS_FT, index_col=0)

data_org = create_data_organization(
    bits_frame_table  = ft_bits,
    cells_frame_table = ft_cells,
    round_bit_color   = round_bit_color,
    readouts          = readouts,
    bits_series       = bits_series,
    cells_series      = cells_series,
    include_dapi      = True,
)

out_name = f"data_organization_{MICROSCOPE.upper()}_{SAMPLE_NAME}.csv"
out_path = METADATA_DIR / out_name
data_org.to_csv(out_path, index=False)
print(f"Saved: {out_path}")
print(f"\n{len(data_org)} rows  ({len(data_org)-1} bits + DAPI)")
data_org

# %% [markdown]
# ## Annotate Dave XML with bit information
#
# Adds per-round XML comments to the Dave config generated by notebook 03.
# - Round 1: comment before the imaging loop
# - Rounds 2+: comment before the fluidics loop that precedes that imaging round
#
# Re-run this cell whenever the round–bit–color mapping changes.

# %%
dave_files = sorted(SETTINGS_DIR.glob("dave-*.xml"))
if not dave_files:
    print("No dave-*.xml found in settings/ — run notebook 03 first.")
else:
    dave_path = dave_files[-1]   # most recently generated
    print(f"Annotating: {dave_path.name}")
    annotate_dave_with_round_info(dave_path, round_bit_color)
    print("Done. Preview of annotated file:")
    with open(dave_path, encoding="ISO-8859-1") as fh:
        print(fh.read())
# Out:
# Annotating: dave-mf3-9hybs-251225_LT027_saving_time.xml
# Done. Preview of annotated file:
# <?xml version="1.0" encoding="ISO-8859-1"?>
# <recipe>
#     <command_sequence>
#
#         <!-- Round 1:
#                 Bit 1 (750 nm)
#                 Bit 2 (650 nm)
#                 Bit 17 (560 nm)
#         -->
#         <loop name="Imaging Round 01">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_01</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 01"/>
#             </movie>
#             <movie>
#                 <name increment="Yes">hal-mf3-epi-cells</name>
#                 <length>27</length>
#                 <parameters>hal-config-mf3-cells-405f25-488f2</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 01"/>
#             </movie>
#         </loop>
#
#         <!-- Round 2:
#                 Bit 3 (750 nm)
#                 Bit 4 (650 nm)
#                 Bit 18 (560 nm)
#         -->
#         <loop name="Fluidics Round 02">
#             <variable_entry name="Fluidics Round 02"/>
#         </loop>
#         <loop name="Imaging Round 02">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_02</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 02"/>
#             </movie>
#         </loop>
#
#         <!-- Round 3:
#                 Bit 5 (750 nm)
#                 Bit 6 (650 nm)
#                 Bit 19 (560 nm)
#         -->
#         <loop name="Fluidics Round 03">
#             <variable_entry name="Fluidics Round 03"/>
#         </loop>
#         <loop name="Imaging Round 03">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_03</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 03"/>
#             </movie>
#         </loop>
#
#         <!-- Round 4:
#                 Bit 7 (750 nm)
#                 Bit 8 (650 nm)
#                 Bit 20 (560 nm)
#         -->
#         <loop name="Fluidics Round 04">
#             <variable_entry name="Fluidics Round 04"/>
#         </loop>
#         <loop name="Imaging Round 04">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_04</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 04"/>
#             </movie>
#         </loop>
#
#         <!-- Round 5:
#                 Bit 9 (750 nm)
#                 Bit 10 (650 nm)
#                 Bit 21 (560 nm)
#         -->
#         <loop name="Fluidics Round 05">
#             <variable_entry name="Fluidics Round 05"/>
#         </loop>
#         <loop name="Imaging Round 05">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_05</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 05"/>
#             </movie>
#         </loop>
#
#         <!-- Round 6:
#                 Bit 11 (750 nm)
#                 Bit 12 (650 nm)
#                 Bit 22 (560 nm)
#         -->
#         <loop name="Fluidics Round 06">
#             <variable_entry name="Fluidics Round 06"/>
#         </loop>
#         <loop name="Imaging Round 06">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_06</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 06"/>
#             </movie>
#         </loop>
#
#         <!-- Round 7:
#                 Bit 13 (750 nm)
#                 Bit 14 (650 nm)
#                 Bit 23 (560 nm)
#         -->
#         <loop name="Fluidics Round 07">
#             <variable_entry name="Fluidics Round 07"/>
#         </loop>
#         <loop name="Imaging Round 07">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_07</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 07"/>
#             </movie>
#         </loop>
#
#         <!-- Round 8:
#                 Bit 15 (750 nm)
#                 Bit 16 (650 nm)
#                 Bit 24 (560 nm)
#         -->
#         <loop name="Fluidics Round 08">
#             <variable_entry name="Fluidics Round 08"/>
#         </loop>
#         <loop name="Imaging Round 08">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_08</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 08"/>
#             </movie>
#         </loop>
#
#         <!-- Round 9:
#                 Bit 25 (750 nm)
#                 Bit 26 (650 nm)
#                 Bit 27 (560 nm)
#         -->
#         <loop name="Fluidics Round 09">
#             <variable_entry name="Fluidics Round 09"/>
#         </loop>
#         <loop name="Imaging Round 09">
#             <movie>
#                 <name increment="Yes">hal-mf3-epi_09</name>
#                 <length>81</length>
#                 <parameters>hal-config-mf3-bits-blkf4-488f2-560f25-650f25-750f25</parameters>
#                 <check_focus>
#                     <num_focus_checks>50</num_focus_checks>
#                     <focus_scan/>
#                 </check_focus>
#                 <overwrite>False</overwrite>
#                 <variable_entry name="Imaging Round 09"/>
#             </movie>
#         </loop>
#     </command_sequence>
#     <loop_variable name="Imaging Round 01">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Imaging Round 02">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Imaging Round 03">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Imaging Round 04">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Imaging Round 05">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Imaging Round 06">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Imaging Round 07">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Imaging Round 08">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Imaging Round 09">
#         <file_path>c:\Users\Leonardo\Dropbox\research\analysis\LineageTracing\251225_LT027_saving_time\positions\positions_251225_LT027_saving_time.txt</file_path>
#     </loop_variable>
#     <loop_variable name="Fluidics Round 02">
#         <value>
#             <valve_protocol>Cleave adaptors</valve_protocol>
#             <valve_protocol>Hyb adaptors 2</valve_protocol>
#             <valve_protocol>Hyb readouts</valve_protocol>
#             <valve_protocol>Flow Image Buffer</valve_protocol>
#         </value>
#     </loop_variable>
#     <loop_variable name="Fluidics Round 03">
#         <value>
#             <valve_protocol>Cleave adaptors</valve_protocol>
#             <valve_protocol>Hyb adaptors 3</valve_protocol>
#             <valve_protocol>Hyb readouts</valve_protocol>
#             <valve_protocol>Flow Image Buffer</valve_protocol>
#         </value>
#     </loop_variable>
#     <loop_variable name="Fluidics Round 04">
#         <value>
#             <valve_protocol>Cleave adaptors</valve_protocol>
#             <valve_protocol>Hyb adaptors 4</valve_protocol>
#             <valve_protocol>Hyb readouts</valve_protocol>
#             <valve_protocol>Flow Image Buffer</valve_protocol>
#         </value>
#     </loop_variable>
#     <loop_variable name="Fluidics Round 05">
#         <value>
#             <valve_protocol>Cleave adaptors</valve_protocol>
#             <valve_protocol>Hyb adaptors 5</valve_protocol>
#             <valve_protocol>Hyb readouts</valve_protocol>
#             <valve_protocol>Flow Image Buffer</valve_protocol>
#         </value>
#     </loop_variable>
#     <loop_variable name="Fluidics Round 06">
#         <value>
#             <valve_protocol>Cleave adaptors</valve_protocol>
#             <valve_protocol>Hyb adaptors 6</valve_protocol>
#             <valve_protocol>Hyb readouts</valve_protocol>
#             <valve_protocol>Flow Image Buffer</valve_protocol>
#         </value>
#     </loop_variable>
#     <loop_variable name="Fluidics Round 07">
#         <value>
#             <valve_protocol>Cleave adaptors</valve_protocol>
#             <valve_protocol>Hyb adaptors 7</valve_protocol>
#             <valve_protocol>Hyb readouts</valve_protocol>
#             <valve_protocol>Flow Image Buffer</valve_protocol>
#         </value>
#     </loop_variable>
#     <loop_variable name="Fluidics Round 08">
#         <value>
#             <valve_protocol>Cleave adaptors</valve_protocol>
#             <valve_protocol>Hyb adaptors 8</valve_protocol>
#             <valve_protocol>Hyb readouts</valve_protocol>
#             <valve_protocol>Flow Image Buffer</valve_protocol>
#         </value>
#     </loop_variable>
#     <loop_variable name="Fluidics Round 09">
#         <value>
#             <valve_protocol>Cleave adaptors</valve_protocol>
#             <valve_protocol>Hyb adaptors 9</valve_protocol>
#             <valve_protocol>Hyb readouts</valve_protocol>
#             <valve_protocol>Flow Image Buffer</valve_protocol>
#         </value>
#     </loop_variable>
# </recipe>
